# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select("table.stats_table")[0]

# %%
links = standings_table.find_all("a")

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if "/squads/" in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/8602292d/Aston-Villa-Stats',
#  'https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats',
#  'https://fbref.com/en/squads/cd051869/Brentford-Stats',
#  'https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  'https://fbref.com/en/squads/943e8050/Burnley-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats',
#  'https://fbref.com/en/squads/d3fd31cc/Everton-Stats',
#  'https://fbref.com/en/squads/fd962109/Fulham-Stats',
#  'https://fbref.com/en/squads/5bfb9659/Leeds-United-Stats',
#  'https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/19538871/Manchester-United-Stats',
#  'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  'https://fbref.com/en/squads/8ef52968/Sunderland-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats',
#  'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats']

# %%
team_url = team_urls[0]

# %%
data = requests.get(team_url)

# %%
import pandas as pd

matches = pd.read_html(data.text, match="Scores & Fixtures")

# %%
matches[0]
# Out:
#           Date   Time            Comp         Round  Day Venue  Result  GF  \
# 0   2025-08-17  16:30  Premier League   Matchweek 1  Sun  Away     NaN NaN
# 1   2025-08-23  17:30  Premier League   Matchweek 2  Sat  Home     NaN NaN
# 2   2025-08-31  16:30  Premier League   Matchweek 3  Sun  Away     NaN NaN
# 3   2025-09-13  12:30  Premier League   Matchweek 4  Sat  Home     NaN NaN
# 4   2025-09-21  16:30  Premier League   Matchweek 5  Sun  Home     NaN NaN
# 5   2025-09-28  16:30  Premier League   Matchweek 6  Sun  Away     NaN NaN
# 6   2025-10-04  15:00  Premier League   Matchweek 7  Sat  Home     NaN NaN
# 7   2025-10-18  15:00  Premier League   Matchweek 8  Sat  Away     NaN NaN
# 8   2025-10-25  15:00  Premier League   Matchweek 9  Sat  Home     NaN NaN
# 9   2025-11-01  15:00  Premier League  Matchweek 10  Sat  Away     NaN NaN
# 10  2025-11-08  15:00  Premier League  Matchweek 11  Sat  Away     NaN NaN
# 11  2025-11-22  15:00  Premier League  Matchweek 12  Sat  Home     NaN NaN
# 12  2025-11-29  15:00  Premier League  Matchweek 13  Sat  Away     NaN NaN
# 13  2025-12-03  20:00  Premier League  Matchweek 14  Wed  Home     NaN NaN
# 14  2025-12-06  15:00  Premier League  Matchweek 15  Sat  Away     NaN NaN
# 15  2025-12-13  15:00  Premier League  Matchweek 16  Sat  Home     NaN NaN
# 16  2025-12-20  15:00  Premier League  Matchweek 17  Sat  Away     NaN NaN
# 17  2025-12-27  15:00  Premier League  Matchweek 18  Sat  Home     NaN NaN
# 18  2025-12-30  20:00  Premier League  Matchweek 19  Tue  Home     NaN NaN
# 19  2026-01-03  15:00  Premier League  Matchweek 20  Sat  Away     NaN NaN
# 20  2026-01-07  20:00  Premier League  Matchweek 21  Wed  Home     NaN NaN
# 21  2026-01-17  15:00  Premier League  Matchweek 22  Sat  Away     NaN NaN
# 22  2026-01-24  15:00  Premier League  Matchweek 23  Sat  Home     NaN NaN
# 23  2026-01-31  15:00  Premier League  Matchweek 24  Sat  Away     NaN NaN
# 24  2026-02-07  15:00  Premier League  Matchweek 25  Sat  Home     NaN NaN
# 25  2026-02-11  20:00  Premier League  Matchweek 26  Wed  Away     NaN NaN
# 26  2026-02-21  15:00  Premier League  Matchweek 27  Sat  Away     NaN NaN
# 27  2026-02-28  15:00  Premier League  Matchweek 28  Sat  Home     NaN NaN
# 28  2026-03-04  20:00  Premier League  Matchweek 29  Wed  Away     NaN NaN
# 29  2026-03-14  15:00  Premier League  Matchweek 30  Sat  Home     NaN NaN
# 30  2026-03-21  15:00  Premier League  Matchweek 31  Sat  Away     NaN NaN
# 31  2026-04-11  15:00  Premier League  Matchweek 32  Sat  Home     NaN NaN
# 32  2026-04-18  15:00  Premier League  Matchweek 33  Sat  Away     NaN NaN
# 33  2026-04-25  15:00  Premier League  Matchweek 34  Sat  Home     NaN NaN
# 34  2026-05-02  15:00  Premier League  Matchweek 35  Sat  Home     NaN NaN
# 35  2026-05-09  15:00  Premier League  Matchweek 36  Sat  Away     NaN NaN
# 36  2026-05-17  15:00  Premier League  Matchweek 37  Sun  Home     NaN NaN
# 37  2026-05-24  16:00  Premier League  Matchweek 38  Sun  Away     NaN NaN
#
#     GA         Opponent  Poss  Attendance  Captain  Formation  Opp Formation  \
# 0  NaN   Manchester Utd   NaN         NaN      NaN        NaN            NaN
# 1  NaN     Leeds United   NaN         NaN      NaN        NaN            NaN
# 2  NaN        Liverpool   NaN         NaN      NaN        NaN            NaN
# 3  NaN  Nott'ham Forest   NaN         NaN      NaN        NaN            NaN
# 4  NaN  Manchester City   NaN         NaN      NaN        NaN            NaN
# 5  NaN    Newcastle Utd   NaN         NaN      NaN        NaN            NaN
# 6  NaN         West Ham   NaN         NaN      NaN        NaN            NaN
# 7  NaN           Fulham   NaN         NaN      NaN        NaN            NaN
# 8  NaN   Crystal Palace   NaN         NaN      NaN        NaN            NaN
# 9  NaN          Burnley   NaN         NaN      NaN        NaN            NaN
# 10 NaN       Sunderland   NaN         NaN      NaN        NaN            NaN
# 11 NaN        Tottenham   NaN         NaN      NaN        NaN            NaN
# 12 NaN          Chelsea   NaN         NaN      NaN        NaN            NaN
# 13 NaN        Brentford   NaN         NaN      NaN        NaN            NaN
# 14 NaN      Aston Villa   NaN         NaN      NaN        NaN            NaN
# 15 NaN           Wolves   NaN         NaN      NaN        NaN            NaN
# 16 NaN          Everton   NaN         NaN      NaN        NaN            NaN
# 17 NaN         Brighton   NaN         NaN      NaN        NaN            NaN
# 18 NaN      Aston Villa   NaN         NaN      NaN        NaN            NaN
# 19 NaN      Bournemouth   NaN         NaN      NaN        NaN            NaN
# 20 NaN        Liverpool   NaN         NaN      NaN        NaN            NaN
# 21 NaN  Nott'ham Forest   NaN         NaN      NaN        NaN            NaN
# 22 NaN   Manchester Utd   NaN         NaN      NaN        NaN            NaN
# 23 NaN     Leeds United   NaN         NaN      NaN        NaN            NaN
# 24 NaN       Sunderland   NaN         NaN      NaN        NaN            NaN
# 25 NaN        Brentford   NaN         NaN      NaN        NaN            NaN
# 26 NaN        Tottenham   NaN         NaN      NaN        NaN            NaN
# 27 NaN          Chelsea   NaN         NaN      NaN        NaN            NaN
# 28 NaN         Brighton   NaN         NaN      NaN        NaN            NaN
# 29 NaN          Everton   NaN         NaN      NaN        NaN            NaN
# 30 NaN           Wolves   NaN         NaN      NaN        NaN            NaN
# 31 NaN      Bournemouth   NaN         NaN      NaN        NaN            NaN
# 32 NaN  Manchester City   NaN         NaN      NaN        NaN            NaN
# 33 NaN    Newcastle Utd   NaN         NaN      NaN        NaN            NaN
# 34 NaN           Fulham   NaN         NaN      NaN        NaN            NaN
# 35 NaN         West Ham   NaN         NaN      NaN        NaN            NaN
# 36 NaN          Burnley   NaN         NaN      NaN        NaN            NaN
# 37 NaN   Crystal Palace   NaN         NaN      NaN        NaN            NaN
#
#     Referee  Match Report  Notes
# 0       NaN  Head-to-Head    NaN
# 1       NaN  Head-to-Head    NaN
# 2       NaN  Head-to-Head    NaN
# 3       NaN  Head-to-Head    NaN
# 4       NaN  Head-to-Head    NaN
# 5       NaN  Head-to-Head    NaN
# 6       NaN  Head-to-Head    NaN
# 7       NaN  Head-to-Head    NaN
# 8       NaN  Head-to-Head    NaN
# 9       NaN  Head-to-Head    NaN
# 10      NaN  Head-to-Head    NaN
# 11      NaN  Head-to-Head    NaN
# 12      NaN  Head-to-Head    NaN
# 13      NaN  Head-to-Head    NaN
# 14      NaN  Head-to-Head    NaN
# 15      NaN  Head-to-Head    NaN
# 16      NaN  Head-to-Head    NaN
# 17      NaN  Head-to-Head    NaN
# 18      NaN  Head-to-Head    NaN
# 19      NaN  Head-to-Head    NaN
# 20      NaN  Head-to-Head    NaN
# 21      NaN  Head-to-Head    NaN
# 22      NaN  Head-to-Head    NaN
# 23      NaN  Head-to-Head    NaN
# 24      NaN  Head-to-Head    NaN
# 25      NaN  Head-to-Head    NaN
# 26      NaN  Head-to-Head    NaN
# 27      NaN  Head-to-Head    NaN
# 28      NaN  Head-to-Head    NaN
# 29      NaN  Head-to-Head    NaN
# 30      NaN  Head-to-Head    NaN
# 31      NaN  Head-to-Head    NaN
# 32      NaN  Head-to-Head    NaN
# 33      NaN  Head-to-Head    NaN
# 34      NaN  Head-to-Head    NaN
# 35      NaN  Head-to-Head    NaN
# 36      NaN  Head-to-Head    NaN
# 37      NaN  Head-to-Head    NaN

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all("a")

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and "all_comps/shooting/" in l]

# %%
links
# Out:
# []
